# %%
import pandas as pd
import os
import numpy as np
from sklearn.preprocessing import StandardScaler

# === Column Definition ===
expected_columns = [
    'time', 'palm_position_x', 'palm_position_y', 'palm_position_z',
    'palm_normal_x', 'palm_normal_y', 'palm_normal_z',
    'palm_direction_x', 'palm_direction_y', 'palm_direction_z',
    'hand_grab_angle', 'hand_grab_strength', 'hand_pinch_angle', 'hand_pinch_strength',
    'thumb_extension', 'index_extension', 'middle_extension', 'ring_extension', 'pinky_extension'
]

# === Utilities ===
def is_row_empty(row):
    return all(pd.isna(cell) or (isinstance(cell, str) and cell.strip() == '') for cell in row)

def trim_leading_empty_rows(df):
    for i in range(len(df)):
        if not is_row_empty(df.iloc[i]):
            return df.iloc[i:].reset_index(drop=True)
    return pd.DataFrame(columns=df.columns)

def trim_trailing_empty_rows(df):
    for i in reversed(range(len(df))):
        if not is_row_empty(df.iloc[i]):
            return df.iloc[:i+1].reset_index(drop=True)
    return pd.DataFrame(columns=df.columns)

def find_trial_split_index(df):
    for i in range(len(df)):
        if is_row_empty(df.iloc[i]):
            if i+1 < len(df) and is_row_empty(df.iloc[i+1]):
                return i
            return i
    return None

def split_trials(df):
    df = trim_leading_empty_rows(df)
    split_idx = find_trial_split_index(df)
    if split_idx is None:
        return df.reset_index(drop=True), pd.DataFrame(columns=df.columns)

    trial1 = df.iloc[:split_idx]
    trial2 = df.iloc[split_idx+1:]

    trial1 = trim_trailing_empty_rows(trial1)
    trial2 = trim_leading_empty_rows(trial2)
    trial2 = trim_trailing_empty_rows(trial2)

    return trial1.reset_index(drop=True), trial2.reset_index(drop=True)
def safe_resample(df_list, time_col, target_rows):
    resampled = []
    for i, df in enumerate(df_list):
        if time_col not in df.columns or df.empty:
            print(f"❌ Skipping trial {i}: Missing or empty time column '{time_col}'")
            continue
        result = resample_by_time(df, time_col, target_rows)
        if result.empty:
            print(f"❌ Skipping trial {i}: Resample failed — likely due to all-NaN time column")
        else:
            resampled.append(result)
    return resampled

def resample_by_time(df, time_col, target_rows):
    df = df.copy()

    # 1. Convert time column to numeric
    df[time_col] = pd.to_numeric(df[time_col], errors='coerce')
    df = df.dropna(subset=[time_col])
    df = df.drop_duplicates(subset=time_col)

    # 2. Convert all other columns to numeric
    for col in df.columns:
        if col != time_col:
            df[col] = pd.to_numeric(df[col], errors='coerce')

    # 3. Resample
    df = df.set_index(time_col)
    new_time_index = np.linspace(df.index.min(), df.index.max(), target_rows)
    df_resampled = df.reindex(new_time_index)
    df_resampled = df_resampled.interpolate(method='linear', axis=0).reset_index()
    df_resampled.rename(columns={'index': time_col}, inplace=True)

    return df_resampled



def standardize_df(df, exclude_cols):
    scaler = StandardScaler()
    cols_to_scale = [col for col in df.columns if col not in exclude_cols]
    df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])
    return df

# === MAIN ===
input_folder = r"C:\Users\Abhay\Downloads\Sheets"
csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]

all_abhay_trial1, all_abhay_trial2 = [], []
all_arjun_trial1, all_arjun_trial2 = [], []
print(f"{file} has {df.shape[1]} columns")

for file in csv_files:
    

    path = os.path.join(input_folder, file)
    try:
        df = pd.read_csv(path, header=None)
        df = df.iloc[1:].reset_index(drop=True)
        df = df.iloc[:, :39]  # 19 Abhay + 1 blank + 19 Arjun

        abhay_df = df.iloc[:, :19].copy()
        arjun_df = df.iloc[:, 20:39].copy()  # ← force 19 columns only
        
        abhay_df.columns = [f"Abhay_{col}" for col in expected_columns]
        arjun_df.columns = [f"Arjun_{col}" for col in expected_columns]
        if "Arjun_time" not in arjun_df.columns:
            print(f"🚫 Arjun_time column missing in {file} — actual columns: {arjun_df.columns.tolist()}")



        abhay_df.dropna(axis=1, how='all', inplace=True)
        arjun_df.dropna(axis=1, how='all', inplace=True)

        abhay_t1, abhay_t2 = split_trials(abhay_df)
        arjun_t1, arjun_t2 = split_trials(arjun_df)


        all_abhay_trial1.append(abhay_t1)
        all_abhay_trial2.append(abhay_t2)
        all_arjun_trial1.append(arjun_t1)
        all_arjun_trial2.append(arjun_t2)

    except Exception as e:
        print(f"Error processing {file}: {e}")

# === Compute median length ===
all_lengths = [len(df) for df in all_abhay_trial1 + all_abhay_trial2 + all_arjun_trial1 + all_arjun_trial2]
median_len = int(np.median(all_lengths))
print(f"Using median trial length: {median_len}")
print("\n=== Trial Lengths Per File ===")
for filename, a1, a2, r1, r2 in zip(csv_files, all_abhay_trial1, all_abhay_trial2, all_arjun_trial1, all_arjun_trial2):
    print(f"{filename}:")
    print(f"  Abhay Trial 1: {len(a1)} rows")
    print(f"  Abhay Trial 2: {len(a2)} rows")
    print(f"  Arjun Trial 1: {len(r1)} rows")
    print(f"  Arjun Trial 2: {len(r2)} rows")


# === Resample ===
all_abhay_trial1 = safe_resample(all_abhay_trial1, 'Abhay_time', median_len)
all_abhay_trial2 = safe_resample(all_abhay_trial2, 'Abhay_time', median_len)
all_arjun_trial1 = safe_resample(all_arjun_trial1, 'Arjun_time', median_len)
all_arjun_trial2 = safe_resample(all_arjun_trial2, 'Arjun_time', median_len)
print("\n=== Trial Lengths Per File ===")
for filename, a1, a2, r1, r2 in zip(csv_files, all_abhay_trial1, all_abhay_trial2, all_arjun_trial1, all_arjun_trial2):
    print(f"{filename}:")
    print(f"  Abhay Trial 1: {len(a1)} rows")
    print(f"  Abhay Trial 2: {len(a2)} rows")
    print(f"  Arjun Trial 1: {len(r1)} rows")
    print(f"  Arjun Trial 2: {len(r2)} rows")

# === Standardize ===
all_abhay_trial1 = [standardize_df(df, ['Abhay_time']) for df in all_abhay_trial1]
all_abhay_trial2 = [standardize_df(df, ['Abhay_time']) for df in all_abhay_trial2]
all_arjun_trial1 = [standardize_df(df, ['Arjun_time']) for df in all_arjun_trial1]
all_arjun_trial2 = [standardize_df(df, ['Arjun_time']) for df in all_arjun_trial2]


# === Optional Save ===
# abhay_trial1_df.to_csv("abhay_trial1_processed.csv", index=False)
# abhay_trial2_df.to_csv("abhay_trial2_processed.csv", index=False)
# arjun_trial1_df.to_csv("arjun_trial1_processed.csv", index=False)
# arjun_trial2_df.to_csv("arjun_trial2_processed.csv", index=False)
# Out:
# Wrench screwing.csv has 39 columns
# Using median trial length: 118
#
# === Trial Lengths Per File ===
# Air Quotes.csv:
#   Abhay Trial 1: 63 rows
#   Abhay Trial 2: 96 rows
#   Arjun Trial 1: 112 rows
#   Arjun Trial 2: 112 rows
# ASL - 1.csv:
#   Abhay Trial 1: 132 rows
#   Abhay Trial 2: 120 rows
#   Arjun Trial 1: 138 rows
#   Arjun Trial 2: 142 rows
# ASL - 10.csv:
#   Abhay Trial 1: 139 rows
#   Abhay Trial 2: 126 rows
#   Arjun Trial 1: 135 rows
#   Arjun Trial 2: 106 rows
# ASL - 2.csv:
#   Abhay Trial 1: 134 rows
#   Abhay Trial 2: 141 rows
#   Arjun Trial 1: 145 rows
#   Arjun Trial 2: 136 rows
# ASL - 3.csv:
#   Abhay Trial 1: 102 rows
#   Abhay Trial 2: 128 rows
#   Arjun Trial 1: 74 rows
#   Arjun Trial 2: 106 rows
# ASL - 4.csv:
#   Abhay Trial 1: 124 rows
#   Abhay Trial 2: 105 rows
#   Arjun Trial 1: 82 rows
#   Arjun Trial 2: 100 rows
# ASL - 5.csv:
#   Abhay Trial 1: 107 rows
#   Abhay Trial 2: 106 rows
#   Arjun Trial 1: 102 rows
#   Arjun Trial 2: 98 rows
# ASL - 6.csv:
#   Abhay Trial 1: 105 rows
#   Abhay Trial 2: 105 rows
#   Arjun Trial 1: 88 rows
#   Arjun Trial 2: 107 rows
# ASL - 7.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 108 rows
#   Arjun Trial 1: 123 rows
#   Arjun Trial 2: 126 rows
# ASL - 8.csv:
#   Abhay Trial 1: 138 rows
#   Abhay Trial 2: 132 rows
#   Arjun Trial 1: 130 rows
#   Arjun Trial 2: 126 rows
# ASL - 9.csv:
#   Abhay Trial 1: 123 rows
#   Abhay Trial 2: 116 rows
#   Arjun Trial 1: 160 rows
#   Arjun Trial 2: 130 rows
# ASL - A.csv:
#   Abhay Trial 1: 139 rows
#   Abhay Trial 2: 130 rows
#   Arjun Trial 1: 129 rows
#   Arjun Trial 2: 143 rows
# ASL - B.csv:
#   Abhay Trial 1: 138 rows
#   Abhay Trial 2: 138 rows
#   Arjun Trial 1: 153 rows
#   Arjun Trial 2: 142 rows
# ASL - Bad.csv:
#   Abhay Trial 1: 99 rows
#   Abhay Trial 2: 75 rows
#   Arjun Trial 1: 115 rows
#   Arjun Trial 2: 127 rows
# ASL - C.csv:
#   Abhay Trial 1: 141 rows
#   Abhay Trial 2: 143 rows
#   Arjun Trial 1: 136 rows
#   Arjun Trial 2: 135 rows
# ASL - D.csv:
#   Abhay Trial 1: 149 rows
#   Abhay Trial 2: 134 rows
#   Arjun Trial 1: 140 rows
#   Arjun Trial 2: 144 rows
# ASL - Drink.csv:
#   Abhay Trial 1: 125 rows
#   Abhay Trial 2: 131 rows
#   Arjun Trial 1: 115 rows
#   Arjun Trial 2: 130 rows
# ASL - E.csv:
#   Abhay Trial 1: 155 rows
#   Abhay Trial 2: 124 rows
#   Arjun Trial 1: 135 rows
#   Arjun Trial 2: 133 rows
# ASL - Eat.csv:
#   Abhay Trial 1: 127 rows
#   Abhay Trial 2: 144 rows
#   Arjun Trial 1: 130 rows
#   Arjun Trial 2: 134 rows
# ASL - F.csv:
#   Abhay Trial 1: 157 rows
#   Abhay Trial 2: 134 rows
#   Arjun Trial 1: 141 rows
#   Arjun Trial 2: 141 rows
# ASL - G.csv:
#   Abhay Trial 1: 128 rows
#   Abhay Trial 2: 141 rows
#   Arjun Trial 1: 136 rows
#   Arjun Trial 2: 141 rows
# ASL - Goodbye.csv:
#   Abhay Trial 1: 134 rows
#   Abhay Trial 2: 134 rows
#   Arjun Trial 1: 131 rows
#   Arjun Trial 2: 134 rows
# ASL - Hello.csv:
#   Abhay Trial 1: 102 rows
#   Abhay Trial 2: 90 rows
#   Arjun Trial 1: 100 rows
#   Arjun Trial 2: 103 rows
# ASL - I love you.csv:
#   Abhay Trial 1: 142 rows
#   Abhay Trial 2: 130 rows
#   Arjun Trial 1: 133 rows
#   Arjun Trial 2: 137 rows
# ASL - I.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 103 rows
#   Arjun Trial 1: 145 rows
#   Arjun Trial 2: 100 rows
# ASL - J.csv:
#   Abhay Trial 1: 121 rows
#   Abhay Trial 2: 123 rows
#   Arjun Trial 1: 110 rows
#   Arjun Trial 2: 94 rows
# ASL - K.csv:
#   Abhay Trial 1: 113 rows
#   Abhay Trial 2: 114 rows
#   Arjun Trial 1: 111 rows
#   Arjun Trial 2: 116 rows
# ASL - L.csv:
#   Abhay Trial 1: 108 rows
#   Abhay Trial 2: 108 rows
#   Arjun Trial 1: 108 rows
#   Arjun Trial 2: 108 rows
# ASL - M.csv:
#   Abhay Trial 1: 110 rows
#   Abhay Trial 2: 111 rows
#   Arjun Trial 1: 111 rows
#   Arjun Trial 2: 103 rows
# ASL - Me.csv:
#   Abhay Trial 1: 114 rows
#   Abhay Trial 2: 134 rows
#   Arjun Trial 1: 136 rows
#   Arjun Trial 2: 126 rows
# ASL - N.csv:
#   Abhay Trial 1: 109 rows
#   Abhay Trial 2: 99 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 110 rows
# ASL - No.csv:
#   Abhay Trial 1: 157 rows
#   Abhay Trial 2: 91 rows
#   Arjun Trial 1: 85 rows
#   Arjun Trial 2: 96 rows
# ASL - O.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 116 rows
#   Arjun Trial 1: 116 rows
#   Arjun Trial 2: 111 rows
# ASL - Q.csv:
#   Abhay Trial 1: 111 rows
#   Abhay Trial 2: 99 rows
#   Arjun Trial 1: 111 rows
#   Arjun Trial 2: 113 rows
# ASL - R.csv:
#   Abhay Trial 1: 135 rows
#   Abhay Trial 2: 96 rows
#   Arjun Trial 1: 102 rows
#   Arjun Trial 2: 132 rows
# ASL - S.csv:
#   Abhay Trial 1: 119 rows
#   Abhay Trial 2: 110 rows
#   Arjun Trial 1: 108 rows
#   Arjun Trial 2: 126 rows
# ASL - T.csv:
#   Abhay Trial 1: 117 rows
#   Abhay Trial 2: 120 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 120 rows
# ASL - Thank you.csv:
#   Abhay Trial 1: 115 rows
#   Abhay Trial 2: 96 rows
#   Arjun Trial 1: 108 rows
#   Arjun Trial 2: 124 rows
# ASL - Tomorrow.csv:
#   Abhay Trial 1: 135 rows
#   Abhay Trial 2: 131 rows
#   Arjun Trial 1: 131 rows
#   Arjun Trial 2: 134 rows
# ASL - U.csv:
#   Abhay Trial 1: 106 rows
#   Abhay Trial 2: 109 rows
#   Arjun Trial 1: 129 rows
#   Arjun Trial 2: 112 rows
# ASL - V.csv:
#   Abhay Trial 1: 115 rows
#   Abhay Trial 2: 116 rows
#   Arjun Trial 1: 119 rows
#   Arjun Trial 2: 118 rows
# ASL - W.csv:
#   Abhay Trial 1: 115 rows
#   Abhay Trial 2: 112 rows
#   Arjun Trial 1: 112 rows
#   Arjun Trial 2: 108 rows
# ASL - X.csv:
#   Abhay Trial 1: 135 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 99 rows
#   Arjun Trial 2: 95 rows
# ASL - Y.csv:
#   Abhay Trial 1: 116 rows
#   Abhay Trial 2: 102 rows
#   Arjun Trial 1: 111 rows
#   Arjun Trial 2: 112 rows
# ASL - Yes.csv:
#   Abhay Trial 1: 89 rows
#   Abhay Trial 2: 110 rows
#   Arjun Trial 1: 99 rows
#   Arjun Trial 2: 105 rows
# ASL - Z.csv:
#   Abhay Trial 1: 113 rows
#   Abhay Trial 2: 112 rows
#   Arjun Trial 1: 107 rows
#   Arjun Trial 2: 103 rows
# Coin Flip.csv:
#   Abhay Trial 1: 129 rows
#   Abhay Trial 2: 135 rows
#   Arjun Trial 1: 146 rows
#   Arjun Trial 2: 132 rows
# Computer Charger.csv:
#   Abhay Trial 1: 145 rows
#   Abhay Trial 2: 138 rows
#   Arjun Trial 1: 120 rows
#   Arjun Trial 2: 111 rows
# Fingers Crossed.csv:
#   Abhay Trial 1: 113 rows
#   Abhay Trial 2: 128 rows
#   Arjun Trial 1: 139 rows
#   Arjun Trial 2: 139 rows
# Fist.csv:
#   Abhay Trial 1: 148 rows
#   Abhay Trial 2: 135 rows
#   Arjun Trial 1: 123 rows
#   Arjun Trial 2: 142 rows
# Flicking.csv:
#   Abhay Trial 1: 87 rows
#   Abhay Trial 2: 100 rows
#   Arjun Trial 1: 101 rows
#   Arjun Trial 2: 89 rows
# Frisbee.csv:
#   Abhay Trial 1: 140 rows
#   Abhay Trial 2: 109 rows
#   Arjun Trial 1: 107 rows
#   Arjun Trial 2: 86 rows
# Grabbing a comb.csv:
#   Abhay Trial 1: 109 rows
#   Abhay Trial 2: 130 rows
#   Arjun Trial 1: 130 rows
#   Arjun Trial 2: 132 rows
# Grabbing a flag.csv:
#   Abhay Trial 1: 137 rows
#   Abhay Trial 2: 115 rows
#   Arjun Trial 1: 139 rows
#   Arjun Trial 2: 111 rows
# Grabbing a marker.csv:
#   Abhay Trial 1: 116 rows
#   Abhay Trial 2: 113 rows
#   Arjun Trial 1: 105 rows
#   Arjun Trial 2: 124 rows
# Grabbing Napkin.csv:
#   Abhay Trial 1: 126 rows
#   Abhay Trial 2: 92 rows
#   Arjun Trial 1: 125 rows
#   Arjun Trial 2: 125 rows
# Grabbing Pen.csv:
#   Abhay Trial 1: 124 rows
#   Abhay Trial 2: 124 rows
#   Arjun Trial 1: 113 rows
#   Arjun Trial 2: 121 rows
# Grabbing Pencil.csv:
#   Abhay Trial 1: 101 rows
#   Abhay Trial 2: 132 rows
#   Arjun Trial 1: 120 rows
#   Arjun Trial 2: 129 rows
# Grabbing toothbrush.csv:
#   Abhay Trial 1: 137 rows
#   Abhay Trial 2: 109 rows
#   Arjun Trial 1: 144 rows
#   Arjun Trial 2: 123 rows
# Hourglass.csv:
#   Abhay Trial 1: 105 rows
#   Abhay Trial 2: 100 rows
#   Arjun Trial 1: 107 rows
#   Arjun Trial 2: 112 rows
# Lemon Squeezer.csv:
#   Abhay Trial 1: 115 rows
#   Abhay Trial 2: 105 rows
#   Arjun Trial 1: 112 rows
#   Arjun Trial 2: 102 rows
# Looking at watch.csv:
#   Abhay Trial 1: 107 rows
#   Abhay Trial 2: 160 rows
#   Arjun Trial 1: 106 rows
#   Arjun Trial 2: 106 rows
# Middle finger.csv:
#   Abhay Trial 1: 106 rows
#   Abhay Trial 2: 154 rows
#   Arjun Trial 1: 139 rows
#   Arjun Trial 2: 137 rows
# Opening a book cover.csv:
#   Abhay Trial 1: 115 rows
#   Abhay Trial 2: 105 rows
#   Arjun Trial 1: 104 rows
#   Arjun Trial 2: 89 rows
# Opening lipstick.csv:
#   Abhay Trial 1: 147 rows
#   Abhay Trial 2: 146 rows
#   Arjun Trial 1: 109 rows
#   Arjun Trial 2: 132 rows
# Opening Plastic Bottle.csv:
#   Abhay Trial 1: 145 rows
#   Abhay Trial 2: 133 rows
#   Arjun Trial 1: 132 rows
#   Arjun Trial 2: 106 rows
# Phone Charger.csv:
#   Abhay Trial 1: 141 rows
#   Abhay Trial 2: 125 rows
#   Arjun Trial 1: 127 rows
#   Arjun Trial 2: 128 rows
# Picking and using nail clipper.csv:
#   Abhay Trial 1: 108 rows
#   Abhay Trial 2: 109 rows
#   Arjun Trial 1: 89 rows
#   Arjun Trial 2: 105 rows
# Picking and using scissors.csv:
#   Abhay Trial 1: 115 rows
#   Abhay Trial 2: 108 rows
#   Arjun Trial 1: 129 rows
#   Arjun Trial 2: 104 rows
# Picking card from deck.csv:
#   Abhay Trial 1: 103 rows
#   Abhay Trial 2: 120 rows
#   Arjun Trial 1: 134 rows
#   Arjun Trial 2: 128 rows
# Picking up a banana.csv:
#   Abhay Trial 1: 100 rows
#   Abhay Trial 2: 110 rows
#   Arjun Trial 1: 103 rows
#   Arjun Trial 2: 102 rows
# Picking up a fidget spinner.csv:
#   Abhay Trial 1: 137 rows
#   Abhay Trial 2: 125 rows
#   Arjun Trial 1: 125 rows
#   Arjun Trial 2: 124 rows
# Picking up a fork.csv:
#   Abhay Trial 1: 81 rows
#   Abhay Trial 2: 78 rows
#   Arjun Trial 1: 82 rows
#   Arjun Trial 2: 76 rows
# Picking up a knife.csv:
#   Abhay Trial 1: 154 rows
#   Abhay Trial 2: 156 rows
#   Arjun Trial 1: 128 rows
#   Arjun Trial 2: 151 rows
# Picking up a mug.csv:
#   Abhay Trial 1: 104 rows
#   Abhay Trial 2: 104 rows
#   Arjun Trial 1: 98 rows
#   Arjun Trial 2: 121 rows
# Picking up a sponn.csv:
#   Abhay Trial 1: 129 rows
#   Abhay Trial 2: 90 rows
#   Arjun Trial 1: 92 rows
#   Arjun Trial 2: 89 rows
# Picking up a tablet.csv:
#   Abhay Trial 1: 109 rows
#   Abhay Trial 2: 125 rows
#   Arjun Trial 1: 130 rows
#   Arjun Trial 2: 123 rows
# Picking up car key.csv:
#   Abhay Trial 1: 110 rows
#   Abhay Trial 2: 128 rows
#   Arjun Trial 1: 119 rows
#   Arjun Trial 2: 150 rows
# Picking up chapstick.csv:
#   Abhay Trial 1: 110 rows
#   Abhay Trial 2: 114 rows
#   Arjun Trial 1: 111 rows
#   Arjun Trial 2: 104 rows
# Picking up flashlight.csv:
#   Abhay Trial 1: 115 rows
#   Abhay Trial 2: 121 rows
#   Arjun Trial 1: 98 rows
#   Arjun Trial 2: 112 rows
# Picking up flyswatter.csv:
#   Abhay Trial 1: 132 rows
#   Abhay Trial 2: 128 rows
#   Arjun Trial 1: 138 rows
#   Arjun Trial 2: 133 rows
# Picking up screwdriver.csv:
#   Abhay Trial 1: 115 rows
#   Abhay Trial 2: 136 rows
#   Arjun Trial 1: 57 rows
#   Arjun Trial 2: 144 rows
# Picking up TV remote.csv:
#   Abhay Trial 1: 104 rows
#   Abhay Trial 2: 120 rows
#   Arjun Trial 1: 89 rows
#   Arjun Trial 2: 97 rows
# Pulling serran wrap.csv:
#   Abhay Trial 1: 128 rows
#   Abhay Trial 2: 128 rows
#   Arjun Trial 1: 124 rows
#   Arjun Trial 2: 133 rows
# Rolling a dice.csv:
#   Abhay Trial 1: 168 rows
#   Abhay Trial 2: 109 rows
#   Arjun Trial 1: 105 rows
#   Arjun Trial 2: 105 rows
# Rolling.csv:
#   Abhay Trial 1: 133 rows
#   Abhay Trial 2: 129 rows
#   Arjun Trial 1: 134 rows
#   Arjun Trial 2: 131 rows
# Salute.csv:
#   Abhay Trial 1: 75 rows
#   Abhay Trial 2: 100 rows
#   Arjun Trial 1: 79 rows
#   Arjun Trial 2: 82 rows
# Scisssor motion.csv:
#   Abhay Trial 1: 152 rows
#   Abhay Trial 2: 107 rows
#   Arjun Trial 1: 135 rows
#   Arjun Trial 2: 115 rows
# Snapping.csv:
#   Abhay Trial 1: 113 rows
#   Abhay Trial 2: 121 rows
#   Arjun Trial 1: 113 rows
#   Arjun Trial 2: 105 rows
# So-so.csv:
#   Abhay Trial 1: 106 rows
#   Abhay Trial 2: 96 rows
#   Arjun Trial 1: 89 rows
#   Arjun Trial 2: 96 rows
# Thumbs up.csv:
#   Abhay Trial 1: 86 rows
#   Abhay Trial 2: 89 rows
#   Arjun Trial 1: 89 rows
#   Arjun Trial 2: 81 rows
# Uncapping toothpaste.csv:
#   Abhay Trial 1: 92 rows
#   Abhay Trial 2: 95 rows
#   Arjun Trial 1: 92 rows
#   Arjun Trial 2: 77 rows
# Using a key.csv:
#   Abhay Trial 1: 130 rows
#   Abhay Trial 2: 134 rows
#   Arjun Trial 1: 139 rows
#   Arjun Trial 2: 141 rows
# Using clothespin.csv:
#   Abhay Trial 1: 132 rows
#   Abhay Trial 2: 111 rows
#   Arjun Trial 1: 127 rows
#   Arjun Trial 2: 101 rows
# Using deoderant.csv:
#   Abhay Trial 1: 138 rows
#   Abhay Trial 2: 127 rows
#   Arjun Trial 1: 105 rows
#   Arjun Trial 2: 110 rows
# Using hand sanitizer.csv:
#   Abhay Trial 1: 107 rows
#   Abhay Trial 2: 109 rows
#   Arjun Trial 1: 134 rows
#   Arjun Trial 2: 108 rows
# Using hose.csv:
#   Abhay Trial 1: 122 rows
#   Abhay Trial 2: 142 rows
#   Arjun Trial 1: 126 rows
#   Arjun Trial 2: 128 rows
# Using Tongs.csv:
#   Abhay Trial 1: 141 rows
#   Abhay Trial 2: 138 rows
#   Arjun Trial 1: 134 rows
#   Arjun Trial 2: 134 rows
# Waving.csv:
#   Abhay Trial 1: 115 rows
#   Abhay Trial 2: 116 rows
#   Arjun Trial 1: 95 rows
#   Arjun Trial 2: 105 rows
# Wrench screwing.csv:
#   Abhay Trial 1: 120 rows
#   Abhay Trial 2: 120 rows
#   Arjun Trial 1: 129 rows
#   Arjun Trial 2: 123 rows
# ❌ Skipping trial 5: Missing or empty time column 'Arjun_time'
# ❌ Skipping trial 5: Missing or empty time column 'Arjun_time'
#
# === Trial Lengths Per File ===
# Air Quotes.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - 1.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - 10.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - 2.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - 3.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - 4.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - 5.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - 6.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - 7.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - 8.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - 9.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - A.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - B.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - Bad.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - C.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - D.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - Drink.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - E.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - Eat.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - F.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - G.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - Goodbye.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - Hello.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - I love you.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - I.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - J.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - K.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - L.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - M.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - Me.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - N.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - No.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - O.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - Q.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - R.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - S.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - T.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - Thank you.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - Tomorrow.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - U.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - V.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - W.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - X.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - Y.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - Yes.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# ASL - Z.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Coin Flip.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Computer Charger.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Fingers Crossed.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Fist.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Flicking.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Frisbee.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Grabbing a comb.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Grabbing a flag.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Grabbing a marker.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Grabbing Napkin.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Grabbing Pen.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Grabbing Pencil.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Grabbing toothbrush.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Hourglass.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Lemon Squeezer.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Looking at watch.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Middle finger.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Opening a book cover.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Opening lipstick.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Opening Plastic Bottle.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Phone Charger.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking and using nail clipper.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking and using scissors.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking card from deck.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking up a banana.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking up a fidget spinner.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking up a fork.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking up a knife.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking up a mug.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking up a sponn.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking up a tablet.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking up car key.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking up chapstick.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking up flashlight.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking up flyswatter.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking up screwdriver.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Picking up TV remote.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Pulling serran wrap.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Rolling a dice.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Rolling.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Salute.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Scisssor motion.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Snapping.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# So-so.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Thumbs up.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Uncapping toothpaste.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Using a key.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Using clothespin.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Using deoderant.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Using hand sanitizer.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Using hose.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Using Tongs.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows
# Waving.csv:
#   Abhay Trial 1: 118 rows
#   Abhay Trial 2: 118 rows
#   Arjun Trial 1: 118 rows
#   Arjun Trial 2: 118 rows

# %%
abhay_cascaded = []
arjun_cascaded = []

for a1, a2 in zip(all_abhay_trial1, all_abhay_trial2):
    if not a1.empty and not a2.empty and a1.shape[0] == median_len and a2.shape[0] == median_len:
        abhay_cascaded.append(cascade_trials(a1, a2, ['Abhay_time']))
    else:
        print("Skipping Abhay trial with unexpected shape.")

for r1, r2 in zip(all_arjun_trial1, all_arjun_trial2):
    if not r1.empty and not r2.empty and r1.shape[0] == median_len and r2.shape[0] == median_len:
        arjun_cascaded.append(cascade_trials(r1, r2, ['Arjun_time']))
    else:
        print("Skipping Arjun trial with unexpected shape.")
print(f"\nCascaded Abhay shape: {abhay_df_final.shape}")
print(f"Cascaded Arjun shape: {arjun_df_final.shape}")
# Out:
# Using median trial length: 118
# Air Quotes.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - 1.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - 10.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - 2.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - 3.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - 4.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - 5.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - 6.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - 7.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - 8.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - 9.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - A.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - B.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - Bad.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - C.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - D.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - Drink.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - E.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - Eat.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - F.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - G.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - Goodbye.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - Hello.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - I love you.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - I.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - J.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - K.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - L.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - M.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - Me.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - N.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - No.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - O.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - Q.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - R.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - S.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - T.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - Thank you.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - Tomorrow.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - U.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - V.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - W.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - X.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - Y.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - Yes.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# ASL - Z.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Coin Flip.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Computer Charger.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Fingers Crossed.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Fist.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Flicking.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Frisbee.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Grabbing a comb.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Grabbing a flag.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Grabbing a marker.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Grabbing Napkin.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Grabbing Pen.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Grabbing Pencil.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Grabbing toothbrush.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Hourglass.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Lemon Squeezer.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Looking at watch.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Middle finger.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Opening a book cover.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Opening lipstick.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Opening Plastic Bottle.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Phone Charger.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking and using nail clipper.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking and using scissors.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking card from deck.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking up a banana.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking up a fidget spinner.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking up a fork.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking up a knife.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking up a mug.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking up a sponn.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking up a tablet.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking up car key.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking up chapstick.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking up flashlight.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking up flyswatter.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking up screwdriver.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Picking up TV remote.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Pulling serran wrap.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Rolling a dice.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Rolling.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Salute.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Scisssor motion.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Snapping.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# So-so.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Thumbs up.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Uncapping toothpaste.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Using a key.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Using clothespin.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Using deoderant.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Using hand sanitizer.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Using hose.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Using Tongs.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
# Waving.csv: Abhay T1=118, T2=118 | Arjun T1=118, T2=118
#
# 🔍 LAST FILE: Wrench screwing.csv
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[177], line 154
#     151 last_idx = valid_filenames.index(last_file)
#     153 print(f"\n🔍 LAST FILE: {last_file}")
# --> 154 print(f"Arjun T1 shape: {all_arjun_trial1[last_idx].shape}")
#     155 print(f"Arjun T2 shape: {all_arjun_trial2[last_idx].shape}")
#     157 # === Standardize ===
#
# IndexError: list index out of range

# %%
arjun_trial2_df['Arjun_time']
# Out:
# 0        0.332724
# 1        0.352683
# 2        0.372642
# 3        0.392601
# 4        0.412560
#            ...
# 11677    2.757203
# 11678    2.779014
# 11679    2.800825
# 11680    2.822637
# 11681    2.844448
# Name: Arjun_time, Length: 11682, dtype: float64

# %%
import pandas as pd
import os
import numpy as np
from sklearn.preprocessing import StandardScaler

# === Column Definition ===
expected_columns = [
    'time', 'palm_position_x', 'palm_position_y', 'palm_position_z',
    'palm_normal_x', 'palm_normal_y', 'palm_normal_z',
    'palm_direction_x', 'palm_direction_y', 'palm_direction_z',
    'hand_grab_angle', 'hand_grab_strength', 'hand_pinch_angle', 'hand_pinch_strength',
    'thumb_extension', 'index_extension', 'middle_extension', 'ring_extension', 'pinky_extension'
]

# === Utilities ===
def is_row_empty(row):
    return all(pd.isna(cell) or (isinstance(cell, str) and cell.strip() == '') for cell in row)

def trim_leading_empty_rows(df):
    for i in range(len(df)):
        if not is_row_empty(df.iloc[i]):
            return df.iloc[i:].reset_index(drop=True)
    return pd.DataFrame(columns=df.columns)

def trim_trailing_empty_rows(df):
    for i in reversed(range(len(df))):
        if not is_row_empty(df.iloc[i]):
            return df.iloc[:i+1].reset_index(drop=True)
    return pd.DataFrame(columns=df.columns)

def find_trial_split_index(df):
    for i in range(len(df)):
        if is_row_empty(df.iloc[i]):
            return i
    return None

def split_trials(df):
    df = trim_leading_empty_rows(df)
    split_idx = find_trial_split_index(df)
    if split_idx is None:
        return df.reset_index(drop=True), pd.DataFrame(columns=df.columns)
    trial1 = df.iloc[:split_idx]
    trial2 = df.iloc[split_idx+1:]
    trial1 = trim_trailing_empty_rows(trial1)
    trial2 = trim_leading_empty_rows(trial2)
    trial2 = trim_trailing_empty_rows(trial2)
    return trial1.reset_index(drop=True), trial2.reset_index(drop=True)

def resample_by_time(df, time_col, target_rows):
    df = df.copy()
    df[time_col] = pd.to_numeric(df[time_col], errors='coerce')
    df = df.dropna(subset=[time_col])
    df = df.drop_duplicates(subset=time_col)
    if df.empty or df[time_col].nunique() < 2:
        print(f"⚠️ Skipping resample: insufficient or invalid time data in column '{time_col}'")
        return pd.DataFrame(columns=[time_col] + [col for col in df.columns if col != time_col])
    for col in df.columns:
        if col != time_col:
            df[col] = pd.to_numeric(df[col], errors='coerce')
    df = df.set_index(time_col)
    new_time_index = np.linspace(df.index.min(), df.index.max(), target_rows)
    df_resampled = df.reindex(new_time_index)
    df_resampled = df_resampled.interpolate(method='linear', axis=0, limit_direction='both').reset_index()
    df_resampled.rename(columns={'index': time_col}, inplace=True)
    return df_resampled

def standardize_df(df, exclude_cols):
    scaler = StandardScaler()
    cols_to_scale = [col for col in df.columns if col not in exclude_cols]
    df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])
    return df

def cascade_trials(trial1, trial2, exclude_cols):
    trial1_flat = trial1[[col for col in trial1.columns if col not in exclude_cols]].to_numpy().T.flatten()
    trial2_flat = trial2[[col for col in trial2.columns if col not in exclude_cols]].to_numpy().T.flatten()
    return np.concatenate([trial1_flat, trial2_flat])

# === Main ===
input_folder = r"C:\Users\Abhay\Downloads\Sheets"
csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]
trial_data = []

# Step 1: Load and split trials
for file in csv_files:
    path = os.path.join(input_folder, file)
    try:
        df = pd.read_csv(path, header=None)
        df = df.iloc[1:].reset_index(drop=True)
        df = df.iloc[:, :39]  # Expecting 19 Abhay + 1 blank + 19 Arjun

        abhay_df = df.iloc[:, :19].copy()
        arjun_df = df.iloc[:, -19:].copy()

        abhay_df.columns = [f"Abhay_{col}" for col in expected_columns]
        arjun_df.columns = [f"Arjun_{col}" for col in expected_columns]

        abhay_df.dropna(axis=1, how='all', inplace=True)
        arjun_df.dropna(axis=1, how='all', inplace=True)

        abhay_t1, abhay_t2 = split_trials(abhay_df)
        arjun_t1, arjun_t2 = split_trials(arjun_df)

        trial_data.append((file, abhay_t1, abhay_t2, arjun_t1, arjun_t2))
    except Exception as e:
        print(f"❌ Error processing {file}: {e}")

# Step 2: Compute median trial length
all_lengths = []
for _, a1, a2, r1, r2 in trial_data:
    all_lengths.extend([len(a1), len(a2), len(r1), len(r2)])
median_len = int(np.median(all_lengths))
print(f"\n📏 Using median trial length: {median_len}")

# Step 3: Resample, standardize, and collect clean files
all_abhay_trial1, all_abhay_trial2 = [], []
all_arjun_trial1, all_arjun_trial2 = [], []
valid_filenames = []

for file, a1, a2, r1, r2 in trial_data:
    if all(not df.empty for df in [a1, a2, r1, r2]):
        if 'Abhay_time' in a1.columns and 'Abhay_time' in a2.columns and 'Arjun_time' in r1.columns and 'Arjun_time' in r2.columns:
            ra1 = resample_by_time(a1, 'Abhay_time', median_len)
            ra2 = resample_by_time(a2, 'Abhay_time', median_len)
            rr1 = resample_by_time(r1, 'Arjun_time', median_len)
            rr2 = resample_by_time(r2, 'Arjun_time', median_len)
        
            if all(not df.empty for df in [ra1, ra2, rr1, rr2]):
                all_abhay_trial1.append(standardize_df(ra1, ['Abhay_time']))
                all_abhay_trial2.append(standardize_df(ra2, ['Abhay_time']))
                all_arjun_trial1.append(standardize_df(rr1, ['Arjun_time']))
                all_arjun_trial2.append(standardize_df(rr2, ['Arjun_time']))
                valid_filenames.append(file)
            else:
                print(f"⚠️ Skipped {file} due to empty resample result.")
        else:
            print(f"🚫 Skipped {file} due to missing time column in one or more trials.")


        if all(not df.empty for df in [ra1, ra2, rr1, rr2]):
            all_abhay_trial1.append(standardize_df(ra1, ['Abhay_time']))
            all_abhay_trial2.append(standardize_df(ra2, ['Abhay_time']))
            all_arjun_trial1.append(standardize_df(rr1, ['Arjun_time']))
            all_arjun_trial2.append(standardize_df(rr2, ['Arjun_time']))
            valid_filenames.append(file)
        else:
            print(f"⚠️ Skipped {file} due to failed resample.")
    else:
        print(f"⚠️ Skipped {file} due to empty trials.")

# Step 4: Cascade
abhay_cascaded = []
arjun_cascaded = []

for i in range(len(valid_filenames)):
    try:
        abhay_cascaded.append(cascade_trials(all_abhay_trial1[i], all_abhay_trial2[i], ['Abhay_time']))
        arjun_cascaded.append(cascade_trials(all_arjun_trial1[i], all_arjun_trial2[i], ['Arjun_time']))
    except Exception as e:
        print(f"❌ Cascade error on {valid_filenames[i]}: {e}")

# Step 5: Final Output
abhay_df_final = pd.DataFrame(abhay_cascaded)
arjun_df_final = pd.DataFrame(arjun_cascaded)

print(f"\n✅ Cascaded Abhay shape: {abhay_df_final.shape}")
print(f"✅ Cascaded Arjun shape: {arjun_df_final.shape}")

# === Optional Save ===
# abhay_df_final.to_csv("abhay_cascaded.csv", index=False)
# arjun_df_final.to_csv("arjun_cascaded.csv", index=False)
# Out:
# 📏 Using median trial length: 118
# 🚫 Skipped ASL - 4.csv due to missing time column in one or more trials.
#
# ✅ Cascaded Abhay shape: (199, 4248)
# ✅ Cascaded Arjun shape: (199, 4248)

# %%
import pandas as pd
import os
import numpy as np
from sklearn.preprocessing import StandardScaler

# === Column Definition ===
expected_columns = [
    'time', 'palm_position_x', 'palm_position_y', 'palm_position_z',
    'palm_normal_x', 'palm_normal_y', 'palm_normal_z',
    'palm_direction_x', 'palm_direction_y', 'palm_direction_z',
    'hand_grab_angle', 'hand_grab_strength', 'hand_pinch_angle', 'hand_pinch_strength',
    'thumb_extension', 'index_extension', 'middle_extension', 'ring_extension', 'pinky_extension'
]

# === Utilities ===
def is_row_empty(row):
    return all(pd.isna(cell) or (isinstance(cell, str) and cell.strip() == '') for cell in row)

def trim_leading_empty_rows(df):
    for i in range(len(df)):
        if not is_row_empty(df.iloc[i]):
            return df.iloc[i:].reset_index(drop=True)
    return pd.DataFrame(columns=df.columns)

def trim_trailing_empty_rows(df):
    for i in reversed(range(len(df))):
        if not is_row_empty(df.iloc[i]):
            return df.iloc[:i+1].reset_index(drop=True)
    return pd.DataFrame(columns=df.columns)

def find_trial_split_index(df):
    for i in range(len(df)):
        if is_row_empty(df.iloc[i]):
            if i+1 < len(df) and is_row_empty(df.iloc[i+1]):
                return i
            return i
    return None

def split_trials(df):
    df = trim_leading_empty_rows(df)
    split_idx = find_trial_split_index(df)
    if split_idx is None:
        return df.reset_index(drop=True), pd.DataFrame(columns=df.columns)

    trial1 = df.iloc[:split_idx]
    trial2 = df.iloc[split_idx+1:]

    trial1 = trim_trailing_empty_rows(trial1)
    trial2 = trim_leading_empty_rows(trial2)
    trial2 = trim_trailing_empty_rows(trial2)

    return trial1.reset_index(drop=True), trial2.reset_index(drop=True)

def resample_by_time(df, time_col, target_rows):
    df = df.copy()

    df[time_col] = pd.to_numeric(df[time_col], errors='coerce')
    df = df.dropna(subset=[time_col])
    df = df.drop_duplicates(subset=time_col)

    for col in df.columns:
        if col != time_col:
            df[col] = pd.to_numeric(df[col], errors='coerce')

    df = df.set_index(time_col)
    new_time_index = np.linspace(df.index.min(), df.index.max(), target_rows)
    df_resampled = df.reindex(new_time_index)
    df_resampled = df_resampled.interpolate(method='linear', axis=0).reset_index()
    df_resampled.rename(columns={'index': time_col}, inplace=True)

    return df_resampled

def safe_resample(df_list, time_col, target_rows):
    resampled = []
    for i, df in enumerate(df_list):
        if time_col not in df.columns or df.empty:
            print(f"⚠️ Skipping resample: Missing or empty {time_col}")
            continue
        resampled.append(resample_by_time(df, time_col, target_rows))
    return resampled


def standardize_df(df, exclude_cols):
    scaler = StandardScaler()
    cols_to_scale = [col for col in df.columns if col not in exclude_cols]
    df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])
    return df

def cascade_df(df):
    return pd.Series(df.to_numpy().T.flatten())

# === MAIN ===
input_folder = r"C:\Users\Abhay\Downloads\Sheets"
csv_files = [f for f in os.listdir(input_folder) if f.endswith('.csv')]

all_abhay_trial1, all_abhay_trial2 = [], []
all_arjun_trial1, all_arjun_trial2 = [], []

for file in csv_files:
    path = os.path.join(input_folder, file)
    try:
        df = pd.read_csv(path, header=None)
        df = df.iloc[1:].reset_index(drop=True)
        df = df.iloc[:, :39]  # 19 Abhay + 1 blank + 19 Arjun

        abhay_df = df.iloc[:, :19].copy()
        arjun_df = df.iloc[:, 20:].copy()
        
        abhay_df.columns = [f"Abhay_{col}" for col in expected_columns]
        arjun_df.columns = [f"Arjun_{col}" for col in expected_columns]

        abhay_df.dropna(axis=1, how='all', inplace=True)
        arjun_df.dropna(axis=1, how='all', inplace=True)

        abhay_t1, abhay_t2 = split_trials(abhay_df)
        arjun_t1, arjun_t2 = split_trials(arjun_df)

        all_abhay_trial1.append(abhay_t1)
        all_abhay_trial2.append(abhay_t2)
        all_arjun_trial1.append(arjun_t1)
        all_arjun_trial2.append(arjun_t2)
        print(f"\nLoaded {len(csv_files)} files.")
        print(f"Abhay Trial 1: {len(all_abhay_trial1)}")
        print(f"Abhay Trial 2: {len(all_abhay_trial2)}")
        print(f"Arjun Trial 1: {len(all_arjun_trial1)}")
        print(f"Arjun Trial 2: {len(all_arjun_trial2)}")


    except Exception as e:
        print(f"Error processing {file}: {e}")

# === Compute median trial length ===
all_lengths = [len(df) for df in all_abhay_trial1 + all_abhay_trial2 + all_arjun_trial1 + all_arjun_trial2]
median_len = int(np.median(all_lengths))
print(f"Using median trial length: {median_len}")

# === Resample all ===
all_abhay_trial1 = safe_resample(all_abhay_trial1, 'Abhay_time', median_len)
all_abhay_trial2 = safe_resample(all_abhay_trial2, 'Abhay_time', median_len)
all_arjun_trial1 = safe_resample(all_arjun_trial1, 'Arjun_time', median_len)
all_arjun_trial2 = safe_resample(all_arjun_trial2, 'Arjun_time', median_len)

# === Standardize all ===
all_abhay_trial1 = [standardize_df(df, ['Abhay_time']) for df in all_abhay_trial1]
all_abhay_trial2 = [standardize_df(df, ['Abhay_time']) for df in all_abhay_trial2]
all_arjun_trial1 = [standardize_df(df, ['Arjun_time']) for df in all_arjun_trial1]
all_arjun_trial2 = [standardize_df(df, ['Arjun_time']) for df in all_arjun_trial2]

# === Cascade (flatten) each trial with printout ===
abhay_cascaded = []
arjun_cascaded = []

print("\n=== Cascading Abhay Trials ===")
for i, (t1, t2) in enumerate(zip(all_abhay_trial1, all_abhay_trial2)):
    print(f"\nAbhay Trial {i+1} - T1 shape: {t1.shape}, T2 shape: {t2.shape}")
    print("T1 Columns:", list(t1.columns))
    print("T2 Columns:", list(t2.columns))
    flat_t1 = cascade_df(t1)
    flat_t2 = cascade_df(t2)
    print(f"Cascaded T1 first 10 entries: {flat_t1.head(10).to_list()}")
    print(f"Cascaded T2 first 10 entries: {flat_t2.head(10).to_list()}")
    cascaded = pd.concat([flat_t1, flat_t2], ignore_index=True)
    print(f"Combined length: {len(cascaded)}")
    abhay_cascaded.append(cascaded)

print("\n=== Cascading Arjun Trials ===")
for i, (t1, t2) in enumerate(zip(all_arjun_trial1, all_arjun_trial2)):
    print(f"\nArjun Trial {i+1} - T1 shape: {t1.shape}, T2 shape: {t2.shape}")
    print("T1 Columns:", list(t1.columns))
    print("T2 Columns:", list(t2.columns))
    flat_t1 = cascade_df(t1)
    flat_t2 = cascade_df(t2)
    print(f"Cascaded T1 first 10 entries: {flat_t1.head(10).to_list()}")
    print(f"Cascaded T2 first 10 entries: {flat_t2.head(10).to_list()}")
    cascaded = pd.concat([flat_t1, flat_t2], ignore_index=True)
    print(f"Combined length: {len(cascaded)}")
    arjun_cascaded.append(cascaded)

# Turn lists of Series into DataFrames
abhay_cascaded = pd.DataFrame(abhay_cascaded)
arjun_cascaded = pd.DataFrame(arjun_cascaded)


# === Final Output ===
print("\nFinal Cascaded Shapes:")
print(f"Abhay final table: {abhay_cascaded.shape}")
print(f"Arjun final table: {arjun_cascaded.shape}")

# === Optional Save ===
# abhay_cascaded.to_csv("abhay_final_table.csv", index=False)
# arjun_cascaded.to_csv("arjun_final_table.csv", index=False)
# Out:
# Loaded 100 files.
# Abhay Trial 1: 1
# Abhay Trial 2: 1
# Arjun Trial 1: 1
# Arjun Trial 2: 1
#
# Loaded 100 files.
# Abhay Trial 1: 2
# Abhay Trial 2: 2
# Arjun Trial 1: 2
# Arjun Trial 2: 2
#
# Loaded 100 files.
# Abhay Trial 1: 3
# Abhay Trial 2: 3
# Arjun Trial 1: 3
# Arjun Trial 2: 3
#
# Loaded 100 files.
# Abhay Trial 1: 4
# Abhay Trial 2: 4
# Arjun Trial 1: 4
# Arjun Trial 2: 4
#
# Loaded 100 files.
# Abhay Trial 1: 5
# Abhay Trial 2: 5
# Arjun Trial 1: 5
# Arjun Trial 2: 5
#
# Loaded 100 files.
# Abhay Trial 1: 6
# Abhay Trial 2: 6
# Arjun Trial 1: 6
# Arjun Trial 2: 6
#
# Loaded 100 files.
# Abhay Trial 1: 7
# Abhay Trial 2: 7
# Arjun Trial 1: 7
# Arjun Trial 2: 7
#
# Loaded 100 files.
# Abhay Trial 1: 8
# Abhay Trial 2: 8
# Arjun Trial 1: 8
# Arjun Trial 2: 8
#
# Loaded 100 files.
# Abhay Trial 1: 9
# Abhay Trial 2: 9
# Arjun Trial 1: 9
# Arjun Trial 2: 9
#
# Loaded 100 files.
# Abhay Trial 1: 10
# Abhay Trial 2: 10
# Arjun Trial 1: 10
# Arjun Trial 2: 10
#
# Loaded 100 files.
# Abhay Trial 1: 11
# Abhay Trial 2: 11
# Arjun Trial 1: 11
# Arjun Trial 2: 11
#
# Loaded 100 files.
# Abhay Trial 1: 12
# Abhay Trial 2: 12
# Arjun Trial 1: 12
# Arjun Trial 2: 12
#
# Loaded 100 files.
# Abhay Trial 1: 13
# Abhay Trial 2: 13
# Arjun Trial 1: 13
# Arjun Trial 2: 13
#
# Loaded 100 files.
# Abhay Trial 1: 14
# Abhay Trial 2: 14
# Arjun Trial 1: 14
# Arjun Trial 2: 14
#
# Loaded 100 files.
# Abhay Trial 1: 15
# Abhay Trial 2: 15
# Arjun Trial 1: 15
# Arjun Trial 2: 15
#
# Loaded 100 files.
# Abhay Trial 1: 16
# Abhay Trial 2: 16
# Arjun Trial 1: 16
# Arjun Trial 2: 16
#
# Loaded 100 files.
# Abhay Trial 1: 17
# Abhay Trial 2: 17
# Arjun Trial 1: 17
# Arjun Trial 2: 17
#
# Loaded 100 files.
# Abhay Trial 1: 18
# Abhay Trial 2: 18
# Arjun Trial 1: 18
# Arjun Trial 2: 18
#
# Loaded 100 files.
# Abhay Trial 1: 19
# Abhay Trial 2: 19
# Arjun Trial 1: 19
# Arjun Trial 2: 19
#
# Loaded 100 files.
# Abhay Trial 1: 20
# Abhay Trial 2: 20
# Arjun Trial 1: 20
# Arjun Trial 2: 20
#
# Loaded 100 files.
# Abhay Trial 1: 21
# Abhay Trial 2: 21
# Arjun Trial 1: 21
# Arjun Trial 2: 21
#
# Loaded 100 files.
# Abhay Trial 1: 22
# Abhay Trial 2: 22
# Arjun Trial 1: 22
# Arjun Trial 2: 22
#
# Loaded 100 files.
# Abhay Trial 1: 23
# Abhay Trial 2: 23
# Arjun Trial 1: 23
# Arjun Trial 2: 23
#
# Loaded 100 files.
# Abhay Trial 1: 24
# Abhay Trial 2: 24
# Arjun Trial 1: 24
# Arjun Trial 2: 24
#
# Loaded 100 files.
# Abhay Trial 1: 25
# Abhay Trial 2: 25
# Arjun Trial 1: 25
# Arjun Trial 2: 25
#
# Loaded 100 files.
# Abhay Trial 1: 26
# Abhay Trial 2: 26
# Arjun Trial 1: 26
# Arjun Trial 2: 26
#
# Loaded 100 files.
# Abhay Trial 1: 27
# Abhay Trial 2: 27
# Arjun Trial 1: 27
# Arjun Trial 2: 27
#
# Loaded 100 files.
# Abhay Trial 1: 28
# Abhay Trial 2: 28
# Arjun Trial 1: 28
# Arjun Trial 2: 28
#
# Loaded 100 files.
# Abhay Trial 1: 29
# Abhay Trial 2: 29
# Arjun Trial 1: 29
# Arjun Trial 2: 29
#
# Loaded 100 files.
# Abhay Trial 1: 30
# Abhay Trial 2: 30
# Arjun Trial 1: 30
# Arjun Trial 2: 30
#
# Loaded 100 files.
# Abhay Trial 1: 31
# Abhay Trial 2: 31
# Arjun Trial 1: 31
# Arjun Trial 2: 31
#
# Loaded 100 files.
# Abhay Trial 1: 32
# Abhay Trial 2: 32
# Arjun Trial 1: 32
# Arjun Trial 2: 32
#
# Loaded 100 files.
# Abhay Trial 1: 33
# Abhay Trial 2: 33
# Arjun Trial 1: 33
# Arjun Trial 2: 33
#
# Loaded 100 files.
# Abhay Trial 1: 34
# Abhay Trial 2: 34
# Arjun Trial 1: 34
# Arjun Trial 2: 34
#
# Loaded 100 files.
# Abhay Trial 1: 35
# Abhay Trial 2: 35
# Arjun Trial 1: 35
# Arjun Trial 2: 35
#
# Loaded 100 files.
# Abhay Trial 1: 36
# Abhay Trial 2: 36
# Arjun Trial 1: 36
# Arjun Trial 2: 36
#
# Loaded 100 files.
# Abhay Trial 1: 37
# Abhay Trial 2: 37
# Arjun Trial 1: 37
# Arjun Trial 2: 37
#
# Loaded 100 files.
# Abhay Trial 1: 38
# Abhay Trial 2: 38
# Arjun Trial 1: 38
# Arjun Trial 2: 38
#
# Loaded 100 files.
# Abhay Trial 1: 39
# Abhay Trial 2: 39
# Arjun Trial 1: 39
# Arjun Trial 2: 39
#
# Loaded 100 files.
# Abhay Trial 1: 40
# Abhay Trial 2: 40
# Arjun Trial 1: 40
# Arjun Trial 2: 40
#
# Loaded 100 files.
# Abhay Trial 1: 41
# Abhay Trial 2: 41
# Arjun Trial 1: 41
# Arjun Trial 2: 41
#
# Loaded 100 files.
# Abhay Trial 1: 42
# Abhay Trial 2: 42
# Arjun Trial 1: 42
# Arjun Trial 2: 42
#
# Loaded 100 files.
# Abhay Trial 1: 43
# Abhay Trial 2: 43
# Arjun Trial 1: 43
# Arjun Trial 2: 43
#
# Loaded 100 files.
# Abhay Trial 1: 44
# Abhay Trial 2: 44
# Arjun Trial 1: 44
# Arjun Trial 2: 44
#
# Loaded 100 files.
# Abhay Trial 1: 45
# Abhay Trial 2: 45
# Arjun Trial 1: 45
# Arjun Trial 2: 45
#
# Loaded 100 files.
# Abhay Trial 1: 46
# Abhay Trial 2: 46
# Arjun Trial 1: 46
# Arjun Trial 2: 46
#
# Loaded 100 files.
# Abhay Trial 1: 47
# Abhay Trial 2: 47
# Arjun Trial 1: 47
# Arjun Trial 2: 47
#
# Loaded 100 files.
# Abhay Trial 1: 48
# Abhay Trial 2: 48
# Arjun Trial 1: 48
# Arjun Trial 2: 48
#
# Loaded 100 files.
# Abhay Trial 1: 49
# Abhay Trial 2: 49
# Arjun Trial 1: 49
# Arjun Trial 2: 49
#
# Loaded 100 files.
# Abhay Trial 1: 50
# Abhay Trial 2: 50
# Arjun Trial 1: 50
# Arjun Trial 2: 50
#
# Loaded 100 files.
# Abhay Trial 1: 51
# Abhay Trial 2: 51
# Arjun Trial 1: 51
# Arjun Trial 2: 51
#
# Loaded 100 files.
# Abhay Trial 1: 52
# Abhay Trial 2: 52
# Arjun Trial 1: 52
# Arjun Trial 2: 52
#
# Loaded 100 files.
# Abhay Trial 1: 53
# Abhay Trial 2: 53
# Arjun Trial 1: 53
# Arjun Trial 2: 53
#
# Loaded 100 files.
# Abhay Trial 1: 54
# Abhay Trial 2: 54
# Arjun Trial 1: 54
# Arjun Trial 2: 54
#
# Loaded 100 files.
# Abhay Trial 1: 55
# Abhay Trial 2: 55
# Arjun Trial 1: 55
# Arjun Trial 2: 55
#
# Loaded 100 files.
# Abhay Trial 1: 56
# Abhay Trial 2: 56
# Arjun Trial 1: 56
# Arjun Trial 2: 56
#
# Loaded 100 files.
# Abhay Trial 1: 57
# Abhay Trial 2: 57
# Arjun Trial 1: 57
# Arjun Trial 2: 57
#
# Loaded 100 files.
# Abhay Trial 1: 58
# Abhay Trial 2: 58
# Arjun Trial 1: 58
# Arjun Trial 2: 58
#
# Loaded 100 files.
# Abhay Trial 1: 59
# Abhay Trial 2: 59
# Arjun Trial 1: 59
# Arjun Trial 2: 59
#
# Loaded 100 files.
# Abhay Trial 1: 60
# Abhay Trial 2: 60
# Arjun Trial 1: 60
# Arjun Trial 2: 60
#
# Loaded 100 files.
# Abhay Trial 1: 61
# Abhay Trial 2: 61
# Arjun Trial 1: 61
# Arjun Trial 2: 61
#
# Loaded 100 files.
# Abhay Trial 1: 62
# Abhay Trial 2: 62
# Arjun Trial 1: 62
# Arjun Trial 2: 62
#
# Loaded 100 files.
# Abhay Trial 1: 63
# Abhay Trial 2: 63
# Arjun Trial 1: 63
# Arjun Trial 2: 63
#
# Loaded 100 files.
# Abhay Trial 1: 64
# Abhay Trial 2: 64
# Arjun Trial 1: 64
# Arjun Trial 2: 64
#
# Loaded 100 files.
# Abhay Trial 1: 65
# Abhay Trial 2: 65
# Arjun Trial 1: 65
# Arjun Trial 2: 65
#
# Loaded 100 files.
# Abhay Trial 1: 66
# Abhay Trial 2: 66
# Arjun Trial 1: 66
# Arjun Trial 2: 66
#
# Loaded 100 files.
# Abhay Trial 1: 67
# Abhay Trial 2: 67
# Arjun Trial 1: 67
# Arjun Trial 2: 67
#
# Loaded 100 files.
# Abhay Trial 1: 68
# Abhay Trial 2: 68
# Arjun Trial 1: 68
# Arjun Trial 2: 68
#
# Loaded 100 files.
# Abhay Trial 1: 69
# Abhay Trial 2: 69
# Arjun Trial 1: 69
# Arjun Trial 2: 69
#
# Loaded 100 files.
# Abhay Trial 1: 70
# Abhay Trial 2: 70
# Arjun Trial 1: 70
# Arjun Trial 2: 70
#
# Loaded 100 files.
# Abhay Trial 1: 71
# Abhay Trial 2: 71
# Arjun Trial 1: 71
# Arjun Trial 2: 71
#
# Loaded 100 files.
# Abhay Trial 1: 72
# Abhay Trial 2: 72
# Arjun Trial 1: 72
# Arjun Trial 2: 72
#
# Loaded 100 files.
# Abhay Trial 1: 73
# Abhay Trial 2: 73
# Arjun Trial 1: 73
# Arjun Trial 2: 73
#
# Loaded 100 files.
# Abhay Trial 1: 74
# Abhay Trial 2: 74
# Arjun Trial 1: 74
# Arjun Trial 2: 74
#
# Loaded 100 files.
# Abhay Trial 1: 75
# Abhay Trial 2: 75
# Arjun Trial 1: 75
# Arjun Trial 2: 75
#
# Loaded 100 files.
# Abhay Trial 1: 76
# Abhay Trial 2: 76
# Arjun Trial 1: 76
# Arjun Trial 2: 76
#
# Loaded 100 files.
# Abhay Trial 1: 77
# Abhay Trial 2: 77
# Arjun Trial 1: 77
# Arjun Trial 2: 77
#
# Loaded 100 files.
# Abhay Trial 1: 78
# Abhay Trial 2: 78
# Arjun Trial 1: 78
# Arjun Trial 2: 78
#
# Loaded 100 files.
# Abhay Trial 1: 79
# Abhay Trial 2: 79
# Arjun Trial 1: 79
# Arjun Trial 2: 79
#
# Loaded 100 files.
# Abhay Trial 1: 80
# Abhay Trial 2: 80
# Arjun Trial 1: 80
# Arjun Trial 2: 80
#
# Loaded 100 files.
# Abhay Trial 1: 81
# Abhay Trial 2: 81
# Arjun Trial 1: 81
# Arjun Trial 2: 81
#
# Loaded 100 files.
# Abhay Trial 1: 82
# Abhay Trial 2: 82
# Arjun Trial 1: 82
# Arjun Trial 2: 82
#
# Loaded 100 files.
# Abhay Trial 1: 83
# Abhay Trial 2: 83
# Arjun Trial 1: 83
# Arjun Trial 2: 83
#
# Loaded 100 files.
# Abhay Trial 1: 84
# Abhay Trial 2: 84
# Arjun Trial 1: 84
# Arjun Trial 2: 84
#
# Loaded 100 files.
# Abhay Trial 1: 85
# Abhay Trial 2: 85
# Arjun Trial 1: 85
# Arjun Trial 2: 85
#
# Loaded 100 files.
# Abhay Trial 1: 86
# Abhay Trial 2: 86
# Arjun Trial 1: 86
# Arjun Trial 2: 86
#
# Loaded 100 files.
# Abhay Trial 1: 87
# Abhay Trial 2: 87
# Arjun Trial 1: 87
# Arjun Trial 2: 87
#
# Loaded 100 files.
# Abhay Trial 1: 88
# Abhay Trial 2: 88
# Arjun Trial 1: 88
# Arjun Trial 2: 88
#
# Loaded 100 files.
# Abhay Trial 1: 89
# Abhay Trial 2: 89
# Arjun Trial 1: 89
# Arjun Trial 2: 89
#
# Loaded 100 files.
# Abhay Trial 1: 90
# Abhay Trial 2: 90
# Arjun Trial 1: 90
# Arjun Trial 2: 90
#
# Loaded 100 files.
# Abhay Trial 1: 91
# Abhay Trial 2: 91
# Arjun Trial 1: 91
# Arjun Trial 2: 91
#
# Loaded 100 files.
# Abhay Trial 1: 92
# Abhay Trial 2: 92
# Arjun Trial 1: 92
# Arjun Trial 2: 92
#
# Loaded 100 files.
# Abhay Trial 1: 93
# Abhay Trial 2: 93
# Arjun Trial 1: 93
# Arjun Trial 2: 93
#
# Loaded 100 files.
# Abhay Trial 1: 94
# Abhay Trial 2: 94
# Arjun Trial 1: 94
# Arjun Trial 2: 94
#
# Loaded 100 files.
# Abhay Trial 1: 95
# Abhay Trial 2: 95
# Arjun Trial 1: 95
# Arjun Trial 2: 95
#
# Loaded 100 files.
# Abhay Trial 1: 96
# Abhay Trial 2: 96
# Arjun Trial 1: 96
# Arjun Trial 2: 96
#
# Loaded 100 files.
# Abhay Trial 1: 97
# Abhay Trial 2: 97
# Arjun Trial 1: 97
# Arjun Trial 2: 97
#
# Loaded 100 files.
# Abhay Trial 1: 98
# Abhay Trial 2: 98
# Arjun Trial 1: 98
# Arjun Trial 2: 98
#
# Loaded 100 files.
# Abhay Trial 1: 99
# Abhay Trial 2: 99
# Arjun Trial 1: 99
# Arjun Trial 2: 99
#
# Loaded 100 files.
# Abhay Trial 1: 100
# Abhay Trial 2: 100
# Arjun Trial 1: 100
# Arjun Trial 2: 100
# Using median trial length: 118
# ⚠️ Skipping resample: Missing or empty Arjun_time
# ⚠️ Skipping resample: Missing or empty Arjun_time
#
# === Cascading Abhay Trials ===
#
# Abhay Trial 1 - T1 shape: (118, 19), T2 shape: (118, 19)
# T1 Columns: ['Abhay_time', 'Abhay_palm_position_x', 'Abhay_palm_position_y', 'Abhay_palm_position_z', 'Abhay_palm_normal_x', 'Abhay_palm_normal_y', 'Abhay_palm_normal_z', 'Abhay_palm_direction_x', 'Abhay_palm_direction_y', 'Abhay_palm_direction_z', 'Abhay_hand_grab_angle', 'Abhay_hand_grab_strength', 'Abhay_hand_pinch_angle', 'Abhay_hand_pinch_strength', 'Abhay_thumb_extension', 'Abhay_index_extension', 'Abhay_middle_extension', 'Abhay_ring_extension', 'Abhay_pinky_extension']
# T2 Columns: ['Abhay_time', 'Abhay_palm_position_x', 'Abhay_palm_position_y', 'Abhay_palm_position_z', 'Abhay_palm_normal_x', 'Abhay_palm_normal_y', 'Abhay_palm_normal_z', 'Abhay_palm_direction_x', 'Abhay_palm_direction_y', 'Abhay_palm_direction_z', 'Abhay_hand_grab_angle', 'Abhay_hand_grab_strength', 'Abhay_hand_pinch_angle', 'Abhay_hand_pinch_strength', 'Abhay_thumb_extension', 'Abhay_index_extension', 'Abhay_middle_extension', 'Abhay_ring_extension', 'Abhay_pinky_extension']
# Cascaded T1 first 10 entries: [0.462307, 0.48149992307692313, 0.5006928461538462, 0.5198857692307692, 0.5390786923076923, 0.5582716153846154, 0.5774645384615384, 0.5966574615384616, 0.6158503846153847, 0.6350433076923078]
# Cascaded T2 first 10 entries: [0.424857, 0.44421935897435894, 0.46358171794871794, 0.4829440769230769, 0.5023064358974358, 0.5216687948717948, 0.5410311538461539, 0.5603935128205129, 0.5797558717948718, 0.5991182307692308]
# Combined length: 4484
#
# Abhay Trial 2 - T1 shape: (118, 19), T2 shape: (118, 19)
# T1 Columns: ['Abhay_time', 'Abhay_palm_position_x', 'Abhay_palm_position_y', 'Abhay_palm_position_z', 'Abhay_palm_normal_x', 'Abhay_palm_normal_y', 'Abhay_palm_normal_z', 'Abhay_palm_direction_x', 'Abhay_palm_direction_y', 'Abhay_palm_direction_z', 'Abhay_hand_grab_angle', 'Abhay_hand_grab_strength', 'Abhay_hand_pinch_angle', 'Abhay_hand_pinch_strength', 'Abhay_thumb_extension', 'Abhay_index_extension', 'Abhay_middle_extension', 'Abhay_ring_extension', 'Abhay_pinky_extension']
# T2 Columns: ['Abhay_time', 'Abhay_palm_position_x', 'Abhay_palm_position_y', 'Abhay_palm_position_z', 'Abhay_palm_normal_x', 'Abhay_palm_normal_y', 'Abhay_palm_normal_z', 'Abhay_palm_direction_x', 'Abhay_palm_direction_y', 'Abhay_palm_direction_z', 'Abhay_hand_grab_angle', 'Abhay_hand_grab_strength', 'Abhay_hand_pinch_angle', 'Abhay_hand_pinch_strength', 'Abhay_thumb_extension', 'Abhay_index_extension', 'Abhay_middle_extension', 'Abhay_ring_extension', 'Abhay_pinky_extension']
# Cascaded T1 first 10 entries: [0.129338, 0.1511544700854701, 0.17297094017094017, 0.19478741025641028, 0.21660388034188036, 0.23842035042735044, 0.26023682051282054, 0.28205329059829065, 0.3038697606837607, 0.32568623076923076]
# Cascaded T2 first 10 entries: [0.305823, 0.326396811965812, 0.3469706239316239, 0.3675444358974359, 0.3881182478632479, 0.4086920598290599, 0.4292658717948718, 0.4498396837606838, 0.4704134957264957, 0.4909873076923077]
# Combined length: 4484
#
# Abhay Trial 3 - T1 shape: (118, 19), T2 shape: (118, 19)
# T1 Columns: ['Abhay_time', 'Abhay_palm_position_x', 'Abhay_palm_position_y', 'Abhay_palm_position_z', 'Abhay_palm_normal_x', 'Abhay_palm_normal_y', 'Abhay_palm_normal_z', 'Abhay_palm_direction_x', 'Abhay_palm_direction_y', 'Abhay_palm_direction_z', 'Abhay_hand_grab_angle', 'Abhay_hand_grab_strength', 'Abhay_hand_pinch_angle', 'Abhay_hand_pinch_strength', 'Abhay_thumb_extension', 'Abhay_index_extension', 'Abhay_middle_extension', 'Abhay_ring_extension', 'Abhay_pinky_extension']
# T2 Columns: ['Abhay_time', 'Abhay_palm_position_x', 'Abhay_palm_position_y', 'Abhay_palm_position_z', 'Abhay_palm_normal_x', 'Abhay_palm_normal_y', 'Abhay_palm_normal_z', 'Abhay_palm_direction_x', 'Abhay_palm_direction_y', 'Abhay_palm_direction_z', 'Abhay_hand_grab_angle', 'Abhay_hand_grab_strength', 'Abhay_hand_pinch_angle', 'Abhay_hand_pinch_strength', 'Abhay_thumb_extension', 'Abhay_index_extension', 'Abhay_middle_extension', 'Abhay_ring_extension', 'Abhay_pinky_extension']
# Cascaded T1 first 10 entries: [0.21867, 0.2393853846153846, 0.26010076923076925, 0.2808161538461539, 0.30153153846153846, 0.3222469230769231, 0.34296230769230773, 0.3636776923076923, 0.38439307692307695, 0.4051084615384616]
# Cascaded T2 first 10 entries: [0.231181, 0.2531545299145299, 0.27512805982905986, 0.29710158974358974, 0.31907511965811963, 0.3410486495726496, 0.3630221794871795, 0.3849957094017094, 0.4069692393162393, 0.42894276923076924]
# Combined length: 4484
#
# Abhay Trial 4 - T1 shape: (118, 19), T2 shape: (118, 19)
# T1 Columns: ['Abhay_time', 'Abhay_palm_position_x', 'Abhay_palm_position_y', 'Abhay_palm_position_z', 'Abhay_palm_normal_x', 'Abhay_palm_normal_y', 'Abhay_palm_normal_z', 'Abhay_palm_direction_x', 'Abhay_palm_direction_y', 'Abhay_palm_direction_z', 'Abhay_hand_grab_angle', 'Abhay_hand_grab_strength', 'Abhay_hand_pinch_angle', 'Abhay_hand_pinch_strength', 'Abhay_thumb_extension', 'Abhay_index_extension', 'Abhay_middle_extension', 'Abhay_ring_extension', 'Abhay_pinky_extension']
# T2 Columns: ['Abhay_time', 'Abhay_palm_position_x', 'Abhay_palm_position_y', 'Abhay_palm_position_z', 'Abhay_palm_normal_x', 'Abhay_palm_normal_y', 'Abhay_palm_normal_z', 'Abhay_palm_direction_x', 'Abhay_palm_direction_y', 'Abhay_palm_direction_z', 'Abhay_hand_grab_angle', 'Abhay_hand_grab_strength', 'Abhay_hand_pinch_angle', 'Abhay_hand_pinch_strength', 'Abhay_thumb_extension', 'Abhay_index_extension', 'Abhay_middle_extension', 'Abhay_ring_extension', 'Abhay_pinky_extension']
# Cascaded T1 first 10 entries: [0
- T1 shape: (118, 19), T2 shape: (118, 19)
# T1 Columns: ['Arjun_time', 'Arjun_palm_position_x', 'Arjun_palm_position_y', 'Arjun_palm_position_z', 'Arjun_palm_normal_x', 'Arjun_palm_normal_y', 'Arjun_palm_normal_z', 'Arjun_palm_direction_x', 'Arjun_palm_direction_y', 'Arjun_palm_direction_z', 'Arjun_hand_grab_angle', 'Arjun_hand_grab_strength', 'Arjun_hand_pinch_angle', 'Arjun_hand_pinch_strength', 'Arjun_thumb_extension', 'Arjun_index_extension', 'Arjun_middle_extension', 'Arjun_ring_extension', 'Arjun_pinky_extension']
# T2 Columns: ['Arjun_time', 'Arjun_palm_position_x', 'Arjun_palm_position_y', 'Arjun_palm_position_z', 'Arjun_palm_normal_x', 'Arjun_palm_normal_y', 'Arjun_palm_normal_z', 'Arjun_palm_direction_x', 'Arjun_palm_direction_y', 'Arjun_palm_direction_z', 'Arjun_hand_grab_angle', 'Arjun_hand_grab_strength', 'Arjun_hand_pinch_angle', 'Arjun_hand_pinch_strength', 'Arjun_thumb_extension', 'Arjun_index_extension', 'Arjun_middle_extension', 'Arjun_ring_extension', 'Arjun_pinky_extension']
# Cascaded T1 first 10 entries: [0.527629, 0.5466107264957265, 0.565592452991453, 0.5845741794871795, 0.603555905982906, 0.6225376324786325, 0.641519358974359, 0.6605010854700855, 0.679482811965812, 0.6984645384615384]
# Cascaded T2 first 10 entries: [0.448697, 0.4680558888888889, 0.4874147777777778, 0.5067736666666667, 0.5261325555555556, 0.5454914444444445, 0.5648503333333333, 0.5842092222222223, 0.6035681111111111, 0.622927]
# Combined length: 4484
#
# Arjun Trial 99 - T1 shape: (118, 19), T2 shape: (118, 19)
# T1 Columns: ['Arjun_time', 'Arjun_palm_position_x', 'Arjun_palm_position_y', 'Arjun_palm_position_z', 'Arjun_palm_normal_x', 'Arjun_palm_normal_y', 'Arjun_palm_normal_z', 'Arjun_palm_direction_x', 'Arjun_palm_direction_y', 'Arjun_palm_direction_z', 'Arjun_hand_grab_angle', 'Arjun_hand_grab_strength', 'Arjun_hand_pinch_angle', 'Arjun_hand_pinch_strength', 'Arjun_thumb_extension', 'Arjun_index_extension', 'Arjun_middle_extension', 'Arjun_ring_extension', 'Arjun_pinky_extension']
# T2 Columns: ['Arjun_time', 'Arjun_palm_position_x', 'Arjun_palm_position_y', 'Arjun_palm_position_z', 'Arjun_palm_normal_x', 'Arjun_palm_normal_y', 'Arjun_palm_normal_z', 'Arjun_palm_direction_x', 'Arjun_palm_direction_y', 'Arjun_palm_direction_z', 'Arjun_hand_grab_angle', 'Arjun_hand_grab_strength', 'Arjun_hand_pinch_angle', 'Arjun_hand_pinch_strength', 'Arjun_thumb_extension', 'Arjun_index_extension', 'Arjun_middle_extension', 'Arjun_ring_extension', 'Arjun_pinky_extension']
# Cascaded T1 first 10 entries: [0.196095, 0.21822757264957265, 0.2403601452991453, 0.2624927179487179, 0.28462529059829056, 0.30675786324786325, 0.3288904358974359, 0.3510230085470085, 0.3731555811965812, 0.3952881538461538]
# Cascaded T2 first 10 entries: [0.292524, 0.31433531623931626, 0.33614663247863247, 0.3579579487179487, 0.37976926495726493, 0.4015805811965812, 0.42339189743589745, 0.44520321367521365, 0.4670145299145299, 0.48882584615384617]
# Combined length: 4484
#
# Final Cascaded Shapes:
# Abhay final table: (100, 4484)
# Arjun final table: (99, 4484)

# %%
arjun_df.head()
# Out:
#   Arjun_time Arjun_palm_position_x Arjun_palm_position_y  \
# 0   0.527629            -18.850277            205.138412
# 1   0.527814            -21.250713            205.505478
# 2   1.021311              39.32402            209.112381
# 3   1.030339             27.043562            205.142303
# 4   1.030611             23.282059            203.692307
#
#   Arjun_palm_position_z Arjun_palm_normal_x Arjun_palm_normal_y  \
# 0             59.485855            -0.06103           -0.993123
# 1             58.560154            -0.05092           -0.992868
# 2             60.334293           -0.046118           -0.987318
# 3             59.409454           -0.058357           -0.987072
# 4             58.796223           -0.068699           -0.986766
#
#   Arjun_palm_normal_z Arjun_palm_direction_x Arjun_palm_direction_y  \
# 0           -0.099906                -0.1747               0.109176
# 1           -0.107798              -0.174473               0.115122
# 2           -0.151911               0.015185               0.151362
# 3           -0.149278                0.00973               0.148964
# 4           -0.146879               0.000986                0.14716
#
#   Arjun_palm_direction_z Arjun_hand_grab_angle Arjun_hand_grab_strength  \
# 0               -0.97855               0.06689                        0
# 1              -0.977909              0.089579                        0
# 2              -0.988362               0.13873                        0
# 3              -0.988795              0.149993                        0
# 4              -0.989112              0.141777                        0
#
#   Arjun_hand_pinch_angle Arjun_hand_pinch_strength Arjun_thumb_extension  \
# 0              58.273132                         0                     1
# 1              58.863861                         0                     1
# 2              58.117531                         0                     1
# 3              58.307758                         0                     1
# 4              58.202579                         0                     1
#
#   Arjun_index_extension Arjun_middle_extension Arjun_ring_extension  \
# 0                     1                      1                    1
# 1                     1                      1                    1
# 2                     1                      1                    1
# 3                     1                      1                    1
# 4                     1                      1                    1
#
#   Arjun_pinky_extension
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
