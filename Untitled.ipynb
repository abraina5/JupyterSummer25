# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# Set your folder path
folder_path = r"C:\Users\Abhay\Downloads\GestureCSVs"

# Get list of all CSV files in the folder
csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

# Dictionary to hold filename and number of rows
gesture_lengths = {}

# Read each CSV and store its length
for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    gesture_lengths[file] = len(df)

# Convert to DataFrame for easy plotting
length_df = pd.DataFrame(list(gesture_lengths.items()), columns=['Gesture', 'Length'])

# Sort by length (optional)
length_df = length_df.sort_values(by='Length', ascending=False)

# Plot the bar graph
plt.figure(figsize=(14, 6))
plt.bar(length_df['Gesture'], length_df['Length'], color='skyblue')
plt.xticks(rotation=90)
plt.title("Number of Rows per Gesture File")
plt.xlabel("Gesture File")
plt.ylabel("Number of Rows")
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

folder_path = r"C:\Users\Abhay\Downloads\GestureCSVs"

csv_files = [file for file in os.listdir(folder_path) if file.endswith('.csv')]

gesture_lengths = {}

for file in csv_files:
    file_path = os.path.join(folder_path, file)
    df = pd.read_csv(file_path)
    gesture_lengths[file] = len(df)

length_df = pd.DataFrame(list(gesture_lengths.items()), columns=['Gesture', 'Length'])
length_df = length_df.sort_values(by='Length', ascending=False)

# Print all lengths in descending order
print("Gesture lengths (descending order):")
print(length_df.to_string(index=False))

# Plot bar chart
plt.figure(figsize=(14, 6))
plt.bar(length_df['Gesture'], length_df['Length'], color='skyblue')
plt.xticks(rotation=90)
plt.title("Number of Rows per Gesture File")
plt.xlabel("Gesture File")
plt.ylabel("Number of Rows")
plt.tight_layout()
plt.show()
# Out:
# Gesture lengths (descending order):
#                            Gesture  Length
#                        ASL - 1.csv     999
#                        ASL - 2.csv     999
#                        ASL - C.csv     999
#                        ASL - D.csv     999
#                        ASL - E.csv     999
#                        ASL - B.csv     999
#                        ASL - G.csv     999
#                        ASL - F.csv     999
#                        ASL - T.csv     999
#                        ASL - S.csv     999
#                        ASL - U.csv     999
#                        ASL - V.csv     999
#                        ASL - W.csv     999
#                        ASL - A.csv     998
#             Picking up a knife.csv     315
#               Opening lipstick.csv     296
#                        ASL - 9.csv     295
#               Computer Charger.csv     288
#                           Fist.csv     286
#                    Using a key.csv     285
#                Fingers Crossed.csv     284
#         Opening Plastic Bottle.csv     283
#                    Using Tongs.csv     283
#                      Coin Flip.csv     282
#                 Rolling a dice.csv     281
#                  Middle finger.csv     280
#          Picking up flyswatter.csv     279
#               ASL - I love you.csv     277
#                      ASL - Eat.csv     275
#                        ASL - 8.csv     274
#                        Rolling.csv     274
#            Grabbing toothbrush.csv     272
#                  ASL - Goodbye.csv     271
#                       ASL - 10.csv     271
#               Looking at watch.csv     271
#                  Phone Charger.csv     271
#                 ASL - Tomorrow.csv     270
#                     Using hose.csv     268
#         Picking card from deck.csv     267
#                Grabbing a comb.csv     266
#                       ASL - Me.csv     266
#    Picking up a fidget spinner.csv     265
#                Scisssor motion.csv     262
#            Pulling serran wrap.csv     260
#            Picking up a tablet.csv     259
#                    ASL - Drink.csv     259
#                        ASL - X.csv     258
#                Wrench screwing.csv     256
#                Grabbing a flag.csv     256
#         Picking up screwdriver.csv     255
#                        Frisbee.csv     253
#                Grabbing Napkin.csv     253
#                        ASL - I.csv     252
#                   Grabbing Pen.csv     252
#                Grabbing Pencil.csv     252
#                        ASL - 7.csv     252
#                       ASL - No.csv     251
#                        ASL - J.csv     249
#                      ASL - Bad.csv     246
#               Using clothespin.csv     246
#           Using hand sanitizer.csv     246
#          Picking up flashlight.csv     240
#                       Snapping.csv     240
#                        ASL - R.csv     240
#                ASL - Thank you.csv     238
#                        ASL - O.csv     238
#     Picking and using scissors.csv     237
#              Grabbing a marker.csv     236
#                        ASL - 3.csv     236
#                         Waving.csv     235
#                        ASL - 4.csv     233
#                        ASL - N.csv     233
#                        ASL - K.csv     231
#                        ASL - Z.csv     230
#                        ASL - Q.csv     228
#           Picking up TV remote.csv     228
#           Picking up chapstick.csv     227
#                        ASL - Y.csv     227
#                     Air Quotes.csv     227
#                        ASL - M.csv     225
#                 Lemon Squeezer.csv     224
#           Opening a book cover.csv     223
#                      Hourglass.csv     223
#             Picking up a sponn.csv     223
#               Picking up a mug.csv     222
#                        ASL - L.csv     221
# Picking and using nail clipper.csv     221
#                        ASL - 5.csv     219
#            Picking up a banana.csv     215
#                        ASL - 6.csv     215
#                    ASL - Hello.csv     209
#                      ASL - Yes.csv     208
#                          So-so.csv     206
#                       Flicking.csv     194
#           Uncapping toothpaste.csv     192
#                         Salute.csv     179
#                      Thumbs up.csv     178
#              Picking up a fork.csv     163
